# %%
import pandas as pd
import numpy as np

# %%
full = pd.read_csv("test3full.csv")
hs = pd.read_csv("final_hs.csv")
es = pd.read_csv("final_es.csv")
ms = pd.read_csv("final_ms.csv")
# Out:
# /Users/thomascurran/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (134,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
full.drop('Unnamed: 0', axis = 1, inplace = True)

for i, c in enumerate(full):
    print(i,c)
# Out:
# 0 Year
# 1 CountyName
# 2 DistrictName
# 3 SchoolName
# 4 SchoolCode
# 5 IndexScore
# 6 LetterGrade
# 7 DistrictCode
# 8 AvgIncome
# 9 AvgPropValADM
# 10 Unemployment
# 11 PovertyRate
# 12 SingleParentFam
# 13 FRL
# 14 College
# 15 HighSchool
# 16 BelowHS
# 17 FallEnrollment
# 18 NonSpEdTeachers
# 19 AvgTeacherSalary
# 20 AdvancedDegrees
# 21 AvgYrsExperience
# 22 SpEdTeachersFTE
# 23 CounselorsFTE
# 24 OtherStaffFTE
# 25 AdministratorsFTE
# 26 SchoolType
# 27 Hispanic%
# 28 NativeAmerican%
# 29 Asian%
# 30 AfricanAmerican%
# 31 PacificIslander%
# 32 White%
# 33 TwoRaces%
# 34 Total
# 35 3_Math_Advanced
# 36 3_Math_Below_Satisfactory
# 37 3_Math_Satisfactory
# 38 3_Reading_Advanced
# 39 3_Reading_Below_Satisfactory
# 40 3_Reading_Satisfactory
# 41 4_Math_Advanced
# 42 4_Math_Below_Satisfactory
# 43 4_Math_Satisfactory
# 44 4_Reading_Advanced
# 45 4_Reading_Below_Satisfactory
# 46 4_Reading_Satisfactory
# 47 5_Math_Advanced
# 48 5_Math_Below_Satisfactory
# 49 5_Math_Satisfactory
# ...
